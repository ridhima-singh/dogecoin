# %% [markdown]
# <a href="https://colab.research.google.com/github/ridhima-singh/dogecoin/blob/main/Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Description: Predict the future price of a DOGECOIN using machine learning, facebook prophet and python

# %%
#import pandas library
import pandas as pd

# %%
#read in the data
df = pd.read_csv('https://raw.githubusercontent.com/ridhima-singh/dogecoin/main/DOGE-USD_1.csv') ##'DOGE-USD (1).csv'
#show the data
df
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 0     2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415    6259550
# 1     2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163    4246520
# 2     2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201    2231080
# 3     2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038    3288960
# 4     2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211    2481270
# ...          ...       ...       ...       ...       ...        ...        ...
# 1516  2022-01-03  0.174406  0.174406  0.168271  0.170088   0.170088  505900382
# 1517  2022-01-04  0.170151  0.172339  0.168128  0.168803   0.168803  541922892
# 1518  2022-01-05  0.168835  0.170747  0.151898  0.159420   0.159420  994086848
# 1519  2022-01-06  0.159436  0.161706  0.155142  0.160213   0.160213  715345645
# 1520  2022-01-07  0.160295  0.160295  0.151446  0.154719   0.154719  953870848
#
# [1521 rows x 7 columns]

# %%
#Select the date and the price
df = df[['Date', 'Close']]
#rename the features: 
df = df.rename(columns={'Date' : 'ds', 'Close' : 'y'})
#show the data
df
# Out:
#               ds         y
# 0     2017-11-09  0.001415
# 1     2017-11-10  0.001163
# 2     2017-11-11  0.001201
# 3     2017-11-12  0.001038
# 4     2017-11-13  0.001211
# ...          ...       ...
# 1516  2022-01-03  0.170088
# 1517  2022-01-04  0.168803
# 1518  2022-01-05  0.159420
# 1519  2022-01-06  0.160213
# 1520  2022-01-07  0.154719
#
# [1521 rows x 2 columns]

# %%
#Get the last 20 rows of data and store them into a new variable
last = df[len(df)-20:]
last
# Out:
#               ds         y
# 1501  2021-12-19  0.169576
# 1502  2021-12-20  0.167322
# 1503  2021-12-21  0.171175
# 1504  2021-12-22  0.173214
# 1505  2021-12-23  0.184490
# 1506  2021-12-24  0.186622
# 1507  2021-12-25  0.190657
# 1508  2021-12-26  0.190020
# 1509  2021-12-27  0.187705
# 1510  2021-12-28  0.174117
# 1511  2021-12-29  0.167765
# 1512  2021-12-30  0.171313
# 1513  2021-12-31  0.170496
# 1514  2022-01-01  0.173035
# 1515  2022-01-02  0.174403
# 1516  2022-01-03  0.170088
# 1517  2022-01-04  0.168803
# 1518  2022-01-05  0.159420
# 1519  2022-01-06  0.160213
# 1520  2022-01-07  0.154719

# %%
#Get all of the rows in the data set except for the last 20 rows of data
df = df[:-20]
df
# Out:
#               ds         y
# 0     2017-11-09  0.001415
# 1     2017-11-10  0.001163
# 2     2017-11-11  0.001201
# 3     2017-11-12  0.001038
# 4     2017-11-13  0.001211
# ...          ...       ...
# 1496  2021-12-14  0.180157
# 1497  2021-12-15  0.181082
# 1498  2021-12-16  0.173454
# 1499  2021-12-17  0.169010
# 1500  2021-12-18  0.172400
#
# [1501 rows x 2 columns]

# %%
  #getting the Facebook prophet library
  from fbprophet import Prophet
  #creating the Prophet object (model)
  fbp = Prophet(daily_seasonality = True)
  #fit/train the model
  fbp.fit(df)
  future = fbp.make_future_dataframe(periods=3652)
  forecast = fbp.predict(future)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
forecast[['ds','yhat']]
forecast.to_csv
# Out:
# <bound method NDFrame.to_csv of              ds     trend  ...  multiplicative_terms_upper      yhat
# 0    2017-11-09  0.008609  ...                         0.0  0.018127
# 1    2017-11-10  0.008366  ...                         0.0  0.018208
# 2    2017-11-11  0.008123  ...                         0.0  0.016516
# 3    2017-11-12  0.007879  ...                         0.0  0.015737
# 4    2017-11-13  0.007636  ...                         0.0  0.013783
# ...         ...       ...  ...                         ...       ...
# 5148 2031-12-14  2.810785  ...                         0.0  2.796971
# 5149 2031-12-15  2.811475  ...                         0.0  2.797889
# 5150 2031-12-16  2.812165  ...                         0.0  2.799253
# 5151 2031-12-17  2.812855  ...                         0.0  2.801256
# 5152 2031-12-18  2.813546  ...                         0.0  2.803184
#
# [5153 rows x 22 columns]>

# %%
#import the facebooks prophet plotting libraies
from fbprophet.plot import plot_plotly
#plot the data
plot_plotly(fbp,forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="42c1f0bd-f8a2-4266-9b56-19e1488f8fef" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("42c1f0bd-f8a2-4266-9b56-19e1488f8fef")) {
#                     Plotly.newPlot(
#                         '42c1f0bd-f8a2-4266-9b56-19e1488f8fef',
# ...

# %%
#show the models prediction for 10-15-2021
forecast[forecast.ds == '2017-11-09']['yhat']
# Out:
# 0    0.018127
# Name: yhat, dtype: float64

# %%
#show actual value for 10-15-2021
last[last.ds == '2017-11-09']['y']
# Out:
# Series([], Name: y, dtype: float64)
